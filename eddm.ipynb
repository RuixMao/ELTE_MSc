# %%
pip install influxdb-client
# Out:
# Requirement already satisfied: influxdb-client in c:\users\irenm\anaconda3\lib\site-packages (1.39.0)
# Requirement already satisfied: reactivex>=4.0.4 in c:\users\irenm\anaconda3\lib\site-packages (from influxdb-client) (4.0.4)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\irenm\anaconda3\lib\site-packages (from influxdb-client) (68.2.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\irenm\anaconda3\lib\site-packages (from influxdb-client) (2.8.2)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\irenm\anaconda3\lib\site-packages (from influxdb-client) (2023.11.17)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\irenm\anaconda3\lib\site-packages (from influxdb-client) (1.26.18)
# Requirement already satisfied: six>=1.5 in c:\users\irenm\anaconda3\lib\site-packages (from python-dateutil>=2.5.3->influxdb-client) (1.16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.1 in c:\users\irenm\anaconda3\lib\site-packages (from reactivex>=4.0.4->influxdb-client) (4.7.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from kafka import KafkaConsumer
from json import loads
import json
from time import sleep
import pandas as pd
from pyspark.sql import SparkSession
import influxdb_client
from influxdb_client.client.write_api import SYNCHRONOUS

# %%
token = "FroEVNbslUfLwbOznZtPjG7mryBVgdiT_O8dIl3mJSHEGRXuZfPSw5jHfL5g2kfxRZlGKhsgJSIWfC_fpH_bbg=="
org = "mema_org"
bucket = "mema_bucket"
url = "http://localhost:8086"

# %%
# Definitions of functions
def calculate_delay_of_detection(true_change_indexes, detected_indexes):
    
    delays = [index - detected_index for detected_index, index in zip(detected_indexes, true_change_indexes)]

    if len(delays) > 0:
        average_delay = sum(delays) / len(delays)
        return average_delay
    else:
        return 0

# %%
def calculate_false_detection_rate(true_change_indexes, detected_indexes):
    total_drifts = len(true_change_indexes)
    total_detected = len(detected_indexes)
    false_detections = total_detected - total_drifts
    fdr = false_detections / total_drifts
    return fdr

# %%
def calculate_miss_detection_rate(true_change_indexes, detected_indexes):
    total_drifts = len(true_change_indexes)
    total_detected = len(detected_indexes)
    mdr = (total_drifts - total_detected) / total_drifts
    return mdr

# %%
def calculate_rate_of_drift(detected_indexes, total_time):
    total_detected = len(detected_indexes)
    rod = total_detected / total_time
    return rod

# %%
import json
from kafka import KafkaConsumer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import joblib

# EDDM Class Definition
class EDDM:
    def __init__(self, alpha=0.95, beta=0.9, min_num_instances=30):
        self.alpha = alpha
        self.beta = beta
        self.min_num_instances = min_num_instances

        self.n = 0
        self.in_concept_change = 0
        self.in_warning_zone = 0
        self.delay = 0
        self.num_errors = 0
        self.last_d = 0
        self.d = 0
        self.mean = 0
        self.std_temp = 0
        self.estimation = 0
        self.m2s_max = 0

    def add_element(self, prediction):
        self.in_concept_change = 0
        self.n += 1

        if prediction == 1.0:
            self.in_warning_zone = 0
            self.delay = 0
            self.num_errors += 1
            self.last_d = self.d
            self.d = self.n - 1
            distance = self.d - self.last_d
            old_mean = self.mean
            self.mean = self.mean + (float(distance) - self.mean) / self.num_errors
            self.std_temp = self.std_temp + (distance - self.mean) * (distance - old_mean)
            std = np.sqrt(self.std_temp / self.num_errors)
            m2s = self.mean + 2 * std

            if self.n < self.min_num_instances:
                return

            if m2s > self.m2s_max:
                self.m2s_max = m2s
            else:
                p = m2s / self.m2s_max
                threshold_warning = (self.mean + 2 * std) / (self.m2s_max + 2 * np.sqrt(self.std_temp))
                threshold_drift = threshold_warning * self.beta

                if (self.num_errors > self.min_num_instances) and (p < self.alpha):
                    self.in_concept_change = 1
                elif (self.num_errors > self.min_num_instances) and (p < self.beta):
                    self.in_warning_zone = 1
                else:
                    self.in_warning_zone = 0

    def detected_warning_zone(self):
        return self.in_warning_zone

    def detected_change(self):
        return self.in_concept_change

# Loading the Random Forest Model
model = joblib.load('../albert/model/random_forest_model.joblib')

# Kafka Consumer Settings
consumer = KafkaConsumer(
    'hai-input',
    bootstrap_servers='localhost:9092',
    auto_offset_reset='earliest',
    enable_auto_commit=True,
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

# Initialise EDDM detector
eddm_detector = EDDM()

# Initialise the list used to collect metrics
change_points = []
accuracies = []
predictions = []
real_labels = []

# Kafka consumption loop
for i, message in consumer:
    message_data = message.value
    df = pd.DataFrame([message_data])
    features = df.drop(['time', 'attack'], axis=1)
    
   # Predict and update drift detectors
    pred = model.predict(features)
    predictions.append(pred[0])
    real_labels.append(df['attack'].iloc[0])

    error_signal = 1 if pred[0] != df['attack'].iloc[0] else 0
    eddm_detector.add_element(error_signal)

    if eddm_detector.detected_change():
        change_points.append(i)

    # Accuracy updated
    if i > 0:
        accuracies.append(accuracy_score(real_labels, predictions))

# Generate graphs of accuracy and change points
plt.figure(figsize=(10, 5))
plt.plot(range(len(accuracies)), accuracies, label='Accuracy')
plt.scatter(change_points, [accuracies[j] for j in change_points], color='red', marker='x', label='Change Point')
plt.title('Change Detection using EDDM with RandomForest on Kafka Data')
plt.xlabel('Message Count')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 91
#      88 real_labels = []
#      90 # Kafka consumption loop
# ---> 91 for i, message in consumer:
#      92     message_data = message.value
#      93     df = pd.DataFrame([message_data])
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\group.py:680, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     677 # Fetch positions if we have partitions we're subscribed to that we
#     678 # don't know the offset for
#     679 if not self._subscription.has_all_fetch_positions():
# --> 680     self._update_fetch_positions(self._subscription.missing_fetch_positions())
#     682 # If data is available already, e.g. from a previous network client
#     683 # poll() call to commit, then just return it immediately
#     684 records, partial = self._fetcher.fetched_records(max_records, update_offsets=update_offsets)
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\group.py:1112, in KafkaConsumer._update_fetch_positions(self, partitions)
#    1109     self._coordinator.refresh_committed_offsets_if_needed()
#    1111 # Then, do any offset lookups in case some positions are not known
# -> 1112 self._fetcher.update_fetch_positions(partitions)
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\fetcher.py:186, in Fetcher.update_fetch_positions(self, partitions)
#     182 elif self._subscriptions.assignment[tp].committed is None:
#     183     # there's no committed position, so we need to reset with the
#     184     # default strategy
#     185     self._subscriptions.need_offset_reset(tp)
# --> 186     self._reset_offset(tp)
#     187 else:
#     188     committed = self._subscriptions.assignment[tp].committed.offset
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\fetcher.py:237, in Fetcher._reset_offset(self, partition)
#     233     raise NoOffsetForPartitionError(partition)
#     235 log.debug("Resetting offset for partition %s to %s offset.",
#     236           partition, strategy)
# --> 237 offsets = self._retrieve_offsets({partition: timestamp})
#     239 if partition in offsets:
#     240     offset = offsets[partition][0]
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\fetcher.py:291, in Fetcher._retrieve_offsets(self, timestamps, timeout_ms)
#     289 if future.exception.invalid_metadata:
#     290     refresh_future = self._client.cluster.request_update()
# --> 291     self._client.poll(future=refresh_future, timeout_ms=remaining_ms)
#     293     # Issue #1780
#     294     # Recheck partition existence after after a successful metadata refresh
#     295     if refresh_future.succeeded() and isinstance(future.exception, Errors.StaleMetadata):
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File c:\Users\irenm\anaconda3\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File c:\Users\irenm\anaconda3\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:

# %%
class HaiConsumer:
    def __init__(self, topic, bootstrap_servers):
        self.topic = topic
        self.bootstrap_servers = bootstrap_servers
        self.consumer = KafkaConsumer(
            self.topic,
            bootstrap_servers=self.bootstrap_servers,
            auto_offset_reset='earliest',
            enable_auto_commit=True,
            value_deserializer=lambda x: loads(x.decode('utf-8')))

    def consume(self):
        # Create an instance of the ADWIN class
        ADWIN_detector = ADWIN()
        # write to file
        with influxdb_client.InfluxDBClient(url=url, token=token, org=org) as client:
            write_api = client.write_api(write_options=SYNCHRONOUS)
            for i, message in enumerate(self.consumer):
                message = message.value
                df = pd.DataFrame([message])
                df = df.iloc[:,1:]

                random_forest_detection = model.predict(df)
                stream_size = df.shape[0]
                # List to store detected change points using ADWIN
                detected_indexes_ADWIN = []
            
                # Update ADWIN with the label (1 for anomaly, 0 for normal)
                ADWIN_detector.set_input(random_forest_detection)
                if ADWIN_detector.get_change():
                    detected_indexes_ADWIN.append(i)

                
                print("Detected Change Points (ADWIN):", detected_indexes_ADWIN)

                # Evaluate change detection performance using ADWIN
                average_delay_ADWIN = calculate_delay_of_detection(random_forest_detection, detected_indexes_ADWIN)
                fdr_ADWIN = calculate_false_detection_rate(random_forest_detection, detected_indexes_ADWIN)
                mdr_ADWIN = calculate_miss_detection_rate(random_forest_detection, detected_indexes_ADWIN)
                rod_ADWIN = calculate_rate_of_drift(detected_indexes_ADWIN, total_time=stream_size - 500)

                p = influxdb_client.Point("Change_Detection_ADWIN").field('fdr_ADWIN', fdr_ADWIN)
                write_api.write(bucket, org, p)

                p = influxdb_client.Point("Change_Detection_ADWIN").field('mdr_ADWIN', mdr_ADWIN)
                write_api.write(bucket, org, p)

                p = influxdb_client.Point("Change_Detection_ADWIN").field('rod_ADWIN', rod_ADWIN)
                write_api.write(bucket, org, p)
                
                sleep(3)
                if i > 100:
                    break

            client.close()

# %%
import joblib

# Load the model from the file
model = joblib.load('../albert/model/random_forest_model.joblib')

# %%
class HaiConsumer:
    def __init__(self, topic, bootstrap_servers):
        self.topic = topic
        self.bootstrap_servers = bootstrap_servers
        self.consumer = KafkaConsumer(
            self.topic,
            bootstrap_servers=self.bootstrap_servers,
            auto_offset_reset='earliest',
            enable_auto_commit=True,
            value_deserializer=lambda x: loads(x.decode('utf-8')))

    def consume(self):
        # Create an instance of the EDDM class
        eddm_detector = EDDM()
        # write to file
        with influxdb_client.InfluxDBClient(url=url, token=token, org=org) as client:
            write_api = client.write_api(write_options=SYNCHRONOUS)
            for i, message in enumerate(self.consumer):
                message = message.value
                # selected_columns = {key: value for key, value in message.items() if key in columns_to_scale_and_monitor}
                df = pd.DataFrame([message])
                df = df.iloc[:,1:]

                random_forest_detection = model.predict(df)
                stream_size = df.shape[0]
                # List to store detected change points using EDDM
                detected_indexes_eddm = []

                # Update EDDM with the label (1 for anomaly, 0 for normal)
                eddm_detector.add_element(random_forest_detection)
                if eddm_detector.detected_change():
                    detected_indexes_eddm.append(i)
                
                print("Detected Change Points (EDDM):", detected_indexes_eddm)


                
                # Evaluate change detection performance using EDDM
                average_delay_eddm = calculate_delay_of_detection(random_forest_detection, detected_indexes_eddm)
                fdr_eddm = calculate_false_detection_rate(random_forest_detection, detected_indexes_eddm)
                mdr_eddm = calculate_miss_detection_rate(random_forest_detection, detected_indexes_eddm)
                rod_eddm = calculate_rate_of_drift(detected_indexes_eddm, total_time=stream_size - 500)

                p = influxdb_client.Point("Change_Detection_EDDM").field('fdr_eddm', fdr_eddm)
                write_api.write(bucket, org, p)

                p = influxdb_client.Point("Change_Detection_EDDM").field('mdr_eddm', mdr_eddm)
                write_api.write(bucket, org, p)
                
                p = influxdb_client.Point("Change_Detection_EDDM").field('rod_eddm', rod_eddm)
                write_api.write(bucket, org, p)
                
                sleep(3)
                if i > 100:
                    break

            client.close()

# %%
topic = 'hai-input'
bootstrap_servers = ['localhost:9092']
consumer = HaiConsumer(topic, bootstrap_servers)
consumer.consume()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 4
#       2 bootstrap_servers = ['localhost:9092']
#       3 consumer = HaiConsumer(topic, bootstrap_servers)
# ----> 4 consumer.consume()
#
# Cell In[11], line 18, in HaiConsumer.consume(self)
#      16 with influxdb_client.InfluxDBClient(url=url, token=token, org=org) as client:
#      17     write_api = client.write_api(write_options=SYNCHRONOUS)
# ---> 18     for i, message in enumerate(self.consumer):
#      19         message = message.value
#      20         # selected_columns = {key: value for key, value in message.items() if key in columns_to_scale_and_monitor}
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\group.py:680, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     677 # Fetch positions if we have partitions we're subscribed to that we
#     678 # don't know the offset for
#     679 if not self._subscription.has_all_fetch_positions():
# --> 680     self._update_fetch_positions(self._subscription.missing_fetch_positions())
#     682 # If data is available already, e.g. from a previous network client
#     683 # poll() call to commit, then just return it immediately
#     684 records, partial = self._fetcher.fetched_records(max_records, update_offsets=update_offsets)
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\group.py:1112, in KafkaConsumer._update_fetch_positions(self, partitions)
#    1109     self._coordinator.refresh_committed_offsets_if_needed()
#    1111 # Then, do any offset lookups in case some positions are not known
# -> 1112 self._fetcher.update_fetch_positions(partitions)
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\fetcher.py:186, in Fetcher.update_fetch_positions(self, partitions)
#     182 elif self._subscriptions.assignment[tp].committed is None:
#     183     # there's no committed position, so we need to reset with the
#     184     # default strategy
#     185     self._subscriptions.need_offset_reset(tp)
# --> 186     self._reset_offset(tp)
#     187 else:
#     188     committed = self._subscriptions.assignment[tp].committed.offset
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\fetcher.py:237, in Fetcher._reset_offset(self, partition)
#     233     raise NoOffsetForPartitionError(partition)
#     235 log.debug("Resetting offset for partition %s to %s offset.",
#     236           partition, strategy)
# --> 237 offsets = self._retrieve_offsets({partition: timestamp})
#     239 if partition in offsets:
#     240     offset = offsets[partition][0]
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\consumer\fetcher.py:291, in Fetcher._retrieve_offsets(self, timestamps, timeout_ms)
#     289 if future.exception.invalid_metadata:
#     290     refresh_future = self._client.cluster.request_update()
# --> 291     self._client.poll(future=refresh_future, timeout_ms=remaining_ms)
#     293     # Issue #1780
#     294     # Recheck partition existence after after a successful metadata refresh
#     295     if refresh_future.succeeded() and isinstance(future.exception, Errors.StaleMetadata):
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File c:\Users\irenm\anaconda3\lib\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File c:\Users\irenm\anaconda3\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File c:\Users\irenm\anaconda3\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:
